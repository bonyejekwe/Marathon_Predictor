# %% [markdown]
# To create `train_all.csv` and `test_all.csv`, run `utils.py` first with the desired dataset size!
#
# To update parameters using `train_all.csv`, run `store_params.r`.

# %%
import numpy as np
import pandas as pd
from utils import get_test_preds, save_param_values, get_race_info 
from plots import tests_and_plots, plot_params
np.random.seed(2025)

race = "all"
train_path, test_path = "processed_data/train_all.csv", "processed_data/test_all.csv"
train, test = pd.read_csv(train_path, index_col=0), pd.read_csv(test_path, index_col=0)
print(train.shape, test.shape)

test = test.sort_values(["lvl", "Race"]).reset_index()
# params = save_param_values(rnd=3)
# get_race_info()

models, baseline = ["S1", "S2", "S3", "S4"], "BL"
test_preds = get_test_preds(test, race, baseline=baseline, full=False)
test_preds
# Out:
# (2400, 30) (2400, 30)
#       index      id dist  curr_pace  total_pace    finish  age gender  year  \
# 0         0   74170   5K   3.720238    3.720238  3.401725   46      M  2024
# 1         1   81272   5K   3.134796    3.134796  2.956903   69      M  2024
# 2         2   69740   5K   3.958828    3.958828  3.752001   47      M  2024
# 3         3   72944   5K   4.022526    4.022526  3.480861   65      M  2024
# 4         4   80672   5K   3.322259    3.322259  2.998508   42      F  2024
# ...     ...     ...  ...        ...         ...       ...  ...    ...   ...
# 2395   2295  121487  40K   4.074980    4.331817  4.319275   39      M  2024
# 2396   2296  150853  40K   2.360718    2.613013  2.609946   55      M  2024
# 2397   2297  163824  40K   2.031694    2.266032  2.256055   27      W  2024
# 2398   2298  141346  40K   2.566735    2.887878  2.879812   45      M  2024
# 2399   2299  123634  40K   3.453039    3.835459  3.809244   35      M  2024
#
# ...

# %%
races_list = ["all", "bos", "nyc", "chi"]
comp_model = "S3"

tables_dict = tests_and_plots(test_data_full=test_preds, races_list=races_list,models=models, 
      baseline=baseline, full_preds=False, comp_model=comp_model, tests_list=["KS", "CVM", "Wilcoxon"])

tables_dict["bos"][1] # print(tables_dict["bos"][0])
# Out:
# File saved: analysis/tables/all_stattest.csv
# File saved for all: error_bar.jpg, error.csv, error_groups.jpg, error_gender_age.jpg
# File saved: analysis/tables/bos_stattest.csv
# File saved for bos: error_bar.jpg, error.csv, error_groups.jpg, error_gender_age.jpg
# File saved: analysis/tables/nyc_stattest.csv
# File saved for nyc: error_bar.jpg, error.csv, error_groups.jpg, error_gender_age.jpg
# File saved: analysis/tables/chi_stattest.csv
# File saved for chi: error_bar.jpg, error.csv, error_groups.jpg, error_gender_age.jpg
#                       BL         S1         S2         S3         S4  \
# 5K             23.090964  14.769850  14.552623  14.761303  14.545450
# 10K            21.888497  13.088193  12.775071  12.183188  12.011014
# 15K            20.319883  11.626016  11.309578  10.356285  10.102717
# 20K            17.622216   9.758430   9.455650   8.365690   8.174438
# 25K            14.300957   7.676329   7.395000   6.250123   6.121333
# ...

# %%
tables_dict2 = tests_and_plots(test_data_full=test_preds, races_list=races_list,
        models=models, baseline=baseline, full_preds=True)

i_check, i_sizes = tables_dict2["all"]
# Out:
# File saved for all: intervals.jpg, sizes.csv, check.csv
# File saved for bos: intervals.jpg, sizes.csv, check.csv
# File saved for nyc: intervals.jpg, sizes.csv, check.csv
# File saved for chi: intervals.jpg, sizes.csv, check.csv

# %%
# from scipy import stats
# from utils import get_data
# train_full, test_full = get_data(size_train=None, size_test=None, train_lis=[2021, 2022, 2023], test_lis=[2024], save=False)
# print(stats.ks_2samp(train["finish"], train_full["finish"]).pvalue)#, stats.anderson_ksamp([train["finish"], train_full["finish"]]).pvalue)
# print(stats.ks_2samp(test["finish"], test_full["finish"]).pvalue)#, stats.anderson_ksamp([test["finish"], test_full["finish"]]).pvalue)
# print()
# for col in ["finish", "curr_pace", "total_pace", "age", "male"]:
#     print(col, stats.ks_2samp(train[col], train_full[col]).pvalue)#, stats.anderson_ksamp([train[col], train_full[col]]).pvalue)
#     print(col, stats.ks_2samp(test[col], test_full[col]).pvalue)#, stats.anderson_ksamp([test[col], test_full[col]]).pvalue)

# %%
# params = pd.read_csv(f"stan_results/params_full3.csv", index_col="Unnamed: 0")
# params.describe().T[["mean", "std", "25%", "50%", "75%"]].round(4)
# plot_params("params3")
